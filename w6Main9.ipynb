# %%
i=3
if i%3:
    print i
else:
    print "no!"
# Out:
# no!

# %%
sum=0
for i in range(0,1000):
    if i%3==0 or i%5==0:
        sum=sum+i
    else:
        print "else"
print sum
# Out:
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# ...
